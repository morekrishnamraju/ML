# %%
import pandas as pd
df=pd.read_csv("StudentPerformanceFactors.csv")
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %%
df.describe(include='all')
# Out:
#         Hours_Studied   Attendance Parental_Involvement Access_to_Resources  \
# count     6607.000000  6607.000000                 6607                6607
# unique            NaN          NaN                    3                   3
# top               NaN          NaN               Medium              Medium
# freq              NaN          NaN                 3362                3319
# mean        19.975329    79.977448                  NaN                 NaN
# std          5.990594    11.547475                  NaN                 NaN
# min          1.000000    60.000000                  NaN                 NaN
# 25%         16.000000    70.000000                  NaN                 NaN
# 50%         20.000000    80.000000                  NaN                 NaN
# 75%         24.000000    90.000000                  NaN                 NaN
# max         44.000000   100.000000                  NaN                 NaN
#
# ...

# %%
df[['Hours_Studied','Attendance']].describe()
# Out:
#        Hours_Studied   Attendance
# count    6607.000000  6607.000000
# mean       19.975329    79.977448
# std         5.990594    11.547475
# min         1.000000    60.000000
# 25%        16.000000    70.000000
# 50%        20.000000    80.000000
# 75%        24.000000    90.000000
# max        44.000000   100.000000

# %%
df.shape
# Out:
# (6607, 20)

# %%
y=df["Exam_Score"]
y.head()
# Out:
# 0    67
# 1    61
# 2    74
# 3    71
# 4    70
# Name: Exam_Score, dtype: int64

# %%
x=df.drop("Exam_Score",axis=1)
x
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
x=df.drop(["Exam_Score","Family_Income","Parental_Involvement","Family_Income","Parental_Education_Level","Distance_from_Home","Gender"],axis=1)
x
# Out:
#       Hours_Studied  Attendance Access_to_Resources  \
# 0                23          84                High
# 1                19          64              Medium
# 2                24          98              Medium
# 3                29          89              Medium
# 4                19          92              Medium
# ...             ...         ...                 ...
# 6602             25          69              Medium
# 6603             23          76              Medium
# 6604             20          90                 Low
# 6605             10          86                High
# 6606             15          67                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                            No            7               73
# 1                            No            8               59
# 2                           Yes            7               91
# 3                           Yes            8               98
# ...

# %%
score_columns=df.filter(like='Score')
score_columns=df[['Exam_Score']]
score_columns.head()
# Out:
#    Exam_Score
# 0          67
# 1          61
# 2          74
# 3          71
# 4          70

# %%
high_scorers=df[df['Exam_Score']>70]
high_scorers.head()
# Out:
#     Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 2              24          98               Medium              Medium
# 3              29          89                  Low              Medium
# 5              19          88               Medium              Medium
# 9              23          98               Medium              Medium
# 11             17          97               Medium                High
#
#    Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 2                         Yes            7               91           Medium
# 3                         Yes            8               98           Medium
# 5                         Yes            8               89           Medium
# 9                         Yes            8               71           Medium
# 11                        Yes            6               87              Low
#
#    Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
male_students=df[df['Gender']=='Male']
male_students
male_students.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 5             19          88               Medium              Medium
# 6             29          84               Medium                 Low
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 5                        Yes            8               89           Medium
# 6                        Yes            7               68              Low
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
female_students=df[(df['Gender']=='Female') & (df['Exam_Score']>70)]
female_students.head()
# Out:
#      Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 73              29          92                  Low              Medium
# 94              18          89                 High              Medium
# 113             35          99                 High                High
# 115             22          89                 High                High
# 118             27          97                  Low                High
#
#     Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 73                          No            4               91           Medium
# 94                         Yes            4               73           Medium
# 113                        Yes            7               85              Low
# 115                        Yes            6               80           Medium
# 118                        Yes            8               81           Medium
#
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      3814
# Female    2793
# Name: count, dtype: int64

# %%
exam_score_array=df['Exam_Score'].to_numpy()
exam_score_array
# Out:
# array([67, 61, 74, ..., 68, 68, 64])

# %%
exam_score_array_2D=df['Exam_Score'].to_numpy().reshape(-1,1)
exam_score_array_2D
# Out:
# array([[67],
#        [61],
#        [74],
#        ...,
#        [68],
#        [68],
#        [64]])

# %%
exam_score_array.shape
# Out:
# (6607,)

# %%
import numpy as np
from numpy._core.defchararray import count
mean_score=np.mean(exam_score_array)
median_score=np.median(exam_score_array)
std_score=np.std(exam_score_array)
min_score=np.min(exam_score_array)
max_score=np.max(exam_score_array)

# %%
import matplotlib.pyplot as plt
plt.hist(exam_score_array,bins=100)
plt.xlabel('Exam Score')
plt.ylabel('Number of students')
plt.title('Distribution of Exam Scores')
plt.show()

# %%
scores,counts=np.unique(exam_score_array,return_counts=True)
plt.bar(scores,counts)
plt.xlabel('Exam Score')
plt.ylabel('Number of students')
plt.title('Bar of Exam Scores')
plt.show()

# %%
scores,counts=np.unique(exam_score_array,return_counts=True)
plt.pie(counts,labels=scores,autopct='%1.1f%%')
plt.title('Pie Chart of Exam Scores')
plt.show()

# %%
hourly_studied_array=df['Hours_Studied'].to_numpy()
plt.scatter(hourly_studied_array,exam_score_array)
plt.xlabel('Hours_Studied')
plt.ylabel('Exam Score')
plt.title('Hours_Studied vs Exam Score')
plt.show()

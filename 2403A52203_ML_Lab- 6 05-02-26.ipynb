# %%
import pandas as pd
df = pd.read_csv("/content/heart_disease_uci.csv")
df.head()
# Out:
#    id     sex
# 0   1    Male
# 1   2    Male
# 2   3    Male
# 3   4    Male
# 4   5  Female

# %%
from sklearn.preprocessing import LabelEncoder

le_sex = LabelEncoder()
df['sex'] = le_sex.fit_transform(df['sex'])
print(df['sex'].value_counts())
# Out:
# sex
# 1    726
# 0    194
# Name: count, dtype: int64

# %%
X = df["id"]
Y = df["sex"]
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 915    0
# 916    1
# 917    1
# 918    1
# 919    1
# Name: sex, Length: 920, dtype: int64

# %%
import numpy as np
from sklearn.model_selection import train_test_split

y = np.array(Y).reshape(-1,1)
x = np.array(X).reshape(-1,1)

x_train, x_test, y_train, y_test = train_test_split(
    x,y, test_size=0.2, random_state=42
)
print("Training Model", x_train);
print("Training Tests", x_test);
# Out:
# Training Model [[881]
#  [458]
#  [798]
#  [ 26]
#  [ 85]
#  [ 11]
#  [347]
#  [549]
#  [637]
#  [595]
#  [409]
#  [119]
#  [303]
#  [329]
#  [ 30]
#  [ 56]
#  [919]
#  [634]
#  [666]
#  [418]
#  [197]
#  [417]
#  [ 82]
#  [918]
#  [391]
#  [571]
#  [514]
#  [894]
#  [205]
#  [212]
#  [737]
#  [661]
#  [299]
#  [276]
#  [550]
#  [372]
#  [786]
#  [750]
#  [282]
#  [752]
#  [412]
#  [ 60]
#  [658]
#  [300]
#  [820]
#  [262]
#  [696]
#  [522]
#  [  8]
#  [251]
#  [156]
#  [366]
#  [449]
#  [102]
#  [200]
#  [618]
#  [363]
#  [381]
#  [605]
#  [343]
#  [457]
#  [535]
#  [332]
#  [  3]
#  [542]
#  [803]
#  [293]
#  [466]
#  [159]
#  [531]
#  [884]
#  [771]
#  [345]
#  [582]
#  [536]
#  [427]
#  [371]
#  [705]
#  [808]
#  [668]
#  [676]
#  [213]
#  [ 80]
#  [149]
#  [825]
#  [793]
#  [399]
#  [448]
#  [421]
#  [134]
#  [491]
#  [559]
#  [364]
#  [482]
#  [651]
#  [484]
#  [356]
#  [849]
#  [602]
#  [899]
#  [173]
#  [478]
#  [870]
#  [835]
#  [828]
#  [ 91]
#  [862]
#  [182]
#  [498]
#  [821]
#  [ 70]
#  [292]
#  [132]
#  [351]
#  [501]
#  [136]
#  [165]
#  [ 29]
#  [517]
#  [194]
#  [324]
#  [588]
#  [170]
#  [885]
#  [141]
#  [174]
#  [  7]
#  [592]
#  [487]
#  [ 74]
#  [629]
#  [802]
#  [583]
#  [146]
#  [235]
#  [221]
#  [839]
#  [713]
#  [133]
#  [483]
#  [768]
#  [186]
#  [ 42]
#  [842]
#  [109]
#  [520]
#  [ 57]
#  [900]
#  [591]
#  [569]
#  [ 25]
#  [369]
#  [454]
#  [597]
#  [ 52]
#  [430]
#  [844]
#  [584]
#  [265]
#  [769]
#  [718]
#  [433]
#  [746]
#  [ 19]
#  [659]
#  [523]
#  [612]
#  [ 84]
#  [ 62]
#  [273]
#  [286]
#  [534]
#  [721]
#  [650]
#  [ 13]
#  [183]
#  [406]
#  [903]
#  [224]
#  [527]
#  [644]
#  [895]
#  [426]
#  [537]
#  [883]
#  [177]
#  [912]
#  [469]
#  [495]
#  [164]
#  [249]
#  [585]
#  [812]
#  [376]
#  [ 75]
#  [114]
#  [524]
#  [515]
#  [105]
#  [115]
#  [863]
#  [ 93]
#  [519]
#  [ 90]
#  [337]
#  [909]
#  [845]
#  [856]
#  [558]
#  [548]
#  [590]
#  [ 95]
#  [ 12]
#  [397]
#  [714]
#  [ 44]
#  [ 43]
#  [330]
#  [168]
#  [804]
#  [552]
#  [695]
#  [101]
#  [179]
#  [598]
#  [809]
#  [833]
#  [178]
#  [486]
#  [623]
#  [731]
#  [630]
#  [384]
#  [258]
#  [657]
#  [336]
#  [683]
#  [ 16]
#  [  4]
#  [434]
#  [257]
#  [479]
#  [502]
#  [437]
#  [394]
#  [223]
#  [180]
#  [480]
#  [443]
#  [325]
#  [545]
#  [ 10]
#  [250]
#  [ 23]
#  [357]
#  [222]
#  [616]
#  [791]
#  [904]
#  [543]
#  [341]
#  [432]
#  [766]
#  [533]
#  [204]
#  [446]
#  [238]
#  [ 94]
#  [513]
#  [910]
#  [736]
#  [285]
#  [185]
#  [740]
#  [435]
#  [508]
#  [154]
#  [ 76]
#  [451]
#  [674]
#  [853]
#  [278]
#  [ 69]
#  [447]
#  [579]
#  [189]
#  [272]
#  [681]
#  [570]
#  [237]
#  [ 89]
#  [782]
#  [118]
#  [126]
#  [753]
#  [290]
#  [239]
#  [  1]
#  [911]
#  [496]
#  [801]
#  [396]
#  [546]
#  [127]
#  [279]
#  [711]
#  [117]
#  [474]
#  [229]
#  [679]
#  [673]
#  [ 58]
#  [530]
#  [275]
#  [319]
#  [621]
#  [145]
#  [652]
#  [573]
#  [837]
#  [660]
#  [370]
#  [269]
#  [639]
#  [308]
#  [424]
#  [311]
#  [355]
#  [ 47]
#  [350]
#  [196]
#  [920]
#  [767]
#  [715]
#  [264]
#  [444]
#  [622]
#  [305]
#  [342]
#  [888]
#  [150]
#  [125]
#  [724]
#  [ 51]
#  [354]
#  [851]
#  [143]
#  [471]
#  [400]
#  [577]
#  [321]
#  [ 20]
#  [745]
#  [846]
#  [744]
#  [408]
#  [538]
#  [636]
#  [ 39]
#  [176]
#  [246]
#  [763]
#  [617]
#  [693]
#  [788]
#  [155]
#  [288]
#  [555]
#  [ 18]
#  [128]
#  [323]
#  [256]
#  [607]
#  [886]
#  [191]
#  [116]
#  [568]
#  [181]
#  [302]
#  [698]
#  [656]
#  [667]
#  [631]
#  [735]
#  [518]
#  [905]
#  [ 46]
#  [834]
#  [158]
#  [707]
#  [172]
#  [ 17]
#  [512]
#  [ 49]
#  [892]
#  [836]
#  [516]
#  [632]
#  [481]
#  [284]
#  [604]
#  [226]
#  [ 27]
#  [817]
#  [438]
#  [873]
#  [365]
#  [230]
#  [ 38]
#  [887]
#  [375]
#  [470]
#  [889]
#  [781]
#  [669]
#  [195]
#  [784]
#  [794]
#  [504]
#  [891]
#  [811]
#  [580]
#  [890]
#  [163]
#  [865]
#  [153]
#  [627]
#  [645]
#  [694]
#  [112]
#  [227]
#  [719]
#  [104]
#  [422]
#  [420]
#  [587]
#  [120]
#  [ 54]
#  [152]
#  [404]
#  [868]
#  [208]
#  [775]
#  [914]
#  [  9]
#  [756]
#  [ 37]
#  [453]
#  [254]
#  [304]
#  [686]
#  [572]
#  [624]
#  [654]
#  [663]
#  [263]
#  [611]
#  [298]
#  [415]
#  [151]
#  [789]
#  [641]
#  [815]
#  [551]
#  [729]
#  [489]
#  [148]
#  [147]
#  [706]
#  [854]
#  [680]
#  [349]
#  [464]
#  [326]
#  [187]
#  [124]
#  [876]
#  [609]
#  [144]
#  [880]
#  [198]
#  [610]
#  [280]
#  [294]
#  [401]
#  [123]
#  [184]
#  [203]
#  [439]
#  [247]
#  [416]
#  [704]
#  [814]
#  [130]
#  [638]
#  [403]
#  [722]
#  [709]
#  [838]
#  [220]
#  [642]
#  [840]
#  [758]
#  [843]
#  [625]
#  [898]
#  [742]
#  [387]
#  [893]
#  [510]
#  [268]
#  [754]
#  [442]
#  [497]
#  [113]
#  [692]
#  [233]
#  [799]
#  [608]
#  [672]
#  [374]
#  [902]
#  [774]
#  [234]
#  [723]
#  [677]
#  [318]
#  [649]
#  [411]
#  [824]
#  [710]
#  [359]
#  [259]
#  [628]
#  [633]
#  [283]
#  [377]
#  [385]
#  [225]
#  [875]
#  [826]
#  [473]
#  [348]
#  [506]
#  [640]
#  [908]
#  [852]
#  [830]
#  [620]
#  [785]
#  [646]
#  [855]
#  [557]
#  [879]
#  [578]
#  [ 86]
#  [243]
#  [699]
#  [160]
#  [525]
#  [ 36]
#  [541]
#  [171]
#  [655]
#  [787]
#  [778]
#  [867]
#  [734]
#  [ 96]
#  [564]
#  [241]
#  [743]
#  [575]
#  [691]
#  [461]
#  [554]
#  [805]
#  [207]
#  [393]
#  [398]
#  [779]
#  [218]
#  [  5]
#  [643]
#  [823]
#  [613]
#  [739]
#  [547]
#  [726]
#  [684]
#  [ 99]
#  [728]
#  [574]
#  [407]
#  [503]
#  [ 48]
#  [ 33]
#  [780]
#  [201]
#  [135]
#  [ 28]
#  [807]
#  [231]
#  [490]
#  [773]
#  [379]
#  [289]
#  [419]
#  [675]
#  [392]
#  [593]
#  [499]
#  [139]
#  [ 63]
#  [472]
#  [648]
#  [129]
#  [897]
#  [521]
#  [ 65]
#  [ 15]
#  [157]
#  [ 41]
#  [493]
#  [380]
#  [188]
#  [764]
#  [217]
#  [792]
#  [ 53]
#  [338]
#  [749]
#  [720]
#  [725]
#  [296]
#  [702]
#  [252]
#  [727]
#  [462]
#  [456]
#  [917]
#  [816]
#  [270]
#  [202]
#  [162]
#  [556]
#  [730]
#  [402]
#  [703]
#  [477]
#  [822]
#  [772]
#  [106]
#  [566]
#  [390]
#  [  2]
#  [860]
#  [562]
#  [ 81]
#  [206]
#  [ 35]
#  [776]
#  [509]
#  [428]
#  [455]
#  [367]
#  [ 92]
#  [340]
#  [565]
#  [346]
#  [777]
#  [242]
#  [ 14]
#  [316]
#  [601]
#  [388]
#  [274]
#  [167]
#  [841]
#  [913]
#  [647]
#  [819]
#  [485]
#  [901]
#  [505]
#  [832]
#  [244]
#  [567]
#  [563]
#  [687]
#  [190]
#  [783]
#  [700]
#  [476]
#  [682]
#  [511]
#  [ 59]
#  [475]
#  [561]
#  [857]
#  [748]
#  [253]
#  [ 22]
#  [314]
#  [460]
#  [161]
#  [277]
#  [192]
#  [386]
#  [806]
#  [414]
#  [492]
#  [344]
#  [770]
#  [309]
#  [662]
#  [131]
#  [664]
#  [872]
#  [100]
#  [373]
#  [ 88]
#  [459]
#  [331]
#  [215]
#  [467]
#  [122]
#  [615]
#  [ 21]
#  [701]
#  [ 72]
#  [107]
#  [271]
#  [861]
#  [436]
#  [103]]
# Training Tests [[320]
#  [378]
#  [539]
#  [297]
#  [532]
#  [ 71]
#  [494]
#  [665]
#  [797]
#  [ 31]
#  [193]
#  [871]
#  [586]
#  [606]
#  [813]
#  [ 87]
#  [322]
#  [362]
#  [ 40]
#  [738]
#  [315]
#  [291]
#  [236]
#  [ 97]
#  [717]
#  [716]
#  [600]
#  [353]
#  [858]
#  [440]
#  [260]
#  [108]
#  [ 64]
#  [121]
#  [445]
#  [757]
#  [ 68]
#  [529]
#  [138]
#  [553]
#  [712]
#  [333]
#  [653]
#  [245]
#  [166]
#  [759]
#  [635]
#  [ 24]
#  [111]
#  [431]
#  [755]
#  [429]
#  [255]
#  [526]
#  [410]
#  [761]
#  [689]
#  [209]
#  [ 73]
#  [540]
#  [312]
#  [368]
#  [678]
#  [708]
#  [560]
#  [878]
#  [465]
#  [850]
#  [441]
#  [810]
#  [796]
#  [ 45]
#  [732]
#  [313]
#  [210]
#  [358]
#  [142]
#  [829]
#  [295]
#  [261]
#  [594]
#  [882]
#  [327]
#  [859]
#  [869]
#  [864]
#  [800]
#  [281]
#  [ 61]
#  [137]
#  [765]
#  [671]
#  [452]
#  [ 67]
#  [335]
#  [500]
#  [228]
#  [232]
#  [425]
#  [240]
#  [488]
#  [219]
#  [267]
#  [544]
#  [307]
#  [140]
#  [599]
#  [916]
#  [ 77]
#  [211]
#  [169]
#  [175]
#  [214]
#  [389]
#  [906]
#  [352]
#  [760]
#  [306]
#  [576]
#  [317]
#  [216]
#  [827]
#  [395]
#  [266]
#  [688]
#  [866]
#  [603]
#  [382]
#  [626]
#  [690]
#  [339]
#  [450]
#  [ 79]
#  [199]
#  [762]
#  [328]
#  [360]
#  [795]
#  [581]
#  [790]
#  [ 66]
#  [847]
#  [896]
#  [614]
#  [831]
#  [507]
#  [848]
#  [741]
#  [ 50]
#  [670]
#  [747]
#  [697]
#  [287]
#  [915]
#  [310]
#  [818]
#  [ 34]
#  [ 32]
#  [874]
#  [423]
#  [528]
#  [877]
#  [110]
#  [ 78]
#  [596]
#  [685]
#  [ 83]
#  [301]
#  [334]
#  [589]
#  [248]
#  [463]
#  [405]
#  [413]
#  [  6]
#  [ 55]
#  [361]
#  [751]
#  [619]
#  [383]
#  [ 98]
#  [907]
#  [468]
#  [733]]

# %%
from sklearn.svm import SVC

svm_linear = SVC(kernel='linear', class_weight="balanced");

# %%
svm_linear.fit(x_train, y_train);
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred = svm_linear.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print("Accuracy Score: ", accuracy_score(y_test, y_pred))
print("Confusion Matrix: \n", confusion_matrix(y_test, y_pred))
print("Classification score: \n", classification_report(y_test, y_pred))
# Out:
# Accuracy Score:  0.5815217391304348
# Confusion Matrix:
#  [[31 13]
#  [64 76]]
# Classification score:
#                precision    recall  f1-score   support
#
#            0       0.33      0.70      0.45        44
#            1       0.85      0.54      0.66       140
#
#     accuracy                           0.58       184
#    macro avg       0.59      0.62      0.55       184
# weighted avg       0.73      0.58      0.61       184

# %%
from sklearn.svm import SVC
svm_rbf= SVC(kernel='rbf', class_weight="balanced")

# %%
svm_rbf.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(class_weight='balanced')

# %%
y_pred_rbf = svm_rbf.predict(x_test)

print("\n--- RBF Kernel SVM ---")
print("Accuracy:", accuracy_score(y_test, y_pred_rbf))
print(classification_report(y_test, y_pred_rbf))
# Out:
# --- RBF Kernel SVM ---
# Accuracy: 0.5652173913043478
#               precision    recall  f1-score   support
#
#            0       0.33      0.77      0.46        44
#            1       0.88      0.50      0.64       140
#
#     accuracy                           0.57       184
#    macro avg       0.60      0.64      0.55       184
# weighted avg       0.74      0.57      0.59       184

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
param_grid = {
    'C': [0.1, 1, 10, 50],
    'gamma': [0.01, 0.1, 1, 'scale']
}
grid = GridSearchCV(
    SVC(kernel='rbf'),
    param_grid,
    cv=5,
    scoring='accuracy',
    verbose=1
)
grid.fit(x_train, y_train.ravel())
best_model = grid.best_estimator_
y_pred_best = best_model.predict(x_test)

print("\n--- Best Tuned RBF SVM ---")
print("Best Parameters:", grid.best_params_)
print("Best Cross-Validation Accuracy:", grid.best_score_)
print("Test Accuracy:", accuracy_score(y_test, y_pred_best))
print("F1 Score:", f1_score(y_test, y_pred_best))
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
#
# --- Best Tuned RBF SVM ---
# Best Parameters: {'C': 1, 'gamma': 1}
# Best Cross-Validation Accuracy: 0.80298768155911
# Test Accuracy: 0.7717391304347826
# F1 Score: 0.8679245283018868
